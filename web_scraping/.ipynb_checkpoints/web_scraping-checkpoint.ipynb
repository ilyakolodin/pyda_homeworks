# %% [markdown]
# # Домашнее задание к лекции "Основы веб-скрапинга и работы с API"

# %% [markdown]
# ## Задание 1.
#
# ### Обязательная часть

# %% [markdown]
# Будем парсить страницу со свежеми новостям на [habr.com/ru/all/](https://habr.com/ru/all/).
#
# Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#
# `KEYWORDS = ['python', 'парсинг']`
#
#  Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
#
# В итоге должен формироваться датафрейм со столбцами: <дата> - <заголовок> - <ссылка>.

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
import time

KEYWORDS = ['python', 'парсинг']
pages = 50
URL_list = ['https://habr.com/ru/all/'] + ['https://habr.com/ru/all/page'+str(x+2)+'/' for x in range(pages-1)]

a_list = []
articles_intro = []
articles_head = []
dates = []

for URL in URL_list:
    req = requests.get(URL)
    time.sleep(0.3)
    soup = BeautifulSoup(req.text, 'html.parser')
    posts = soup.find_all('article', class_='post post_preview')

    articles_head_with_href = list(map(lambda x: x.find('a', class_='post__title_link'), posts))
    a_list += list(map(lambda x: x.get('href'), articles_head_with_href))
    articles_intro += list(map(lambda x: x.find('div', class_='post__body post__body_crop').text, posts))
    articles_head += list(map(lambda x: x.text, articles_head_with_href))
    dates += list(map(lambda x: x.find('span', class_='post__time').text, posts))

# %%
import pandas as pd

# %%
news = pd.DataFrame({'date': dates, 'header':articles_head, 'intro':articles_intro, 'a': a_list})
news.head()
# Out:
#               date                                             header  \
# 0  сегодня в 00:31  Всё о проекте «Спутниковый интернет Starlink»....
# 1  сегодня в 00:20  Динамика квадро-, гекса- и октокоптеров. Модел...
# 2    вчера в 23:28   Как подружить .NET и IDA Pro (о дружбе C# и C++)
# 3    вчера в 23:16  Как в enterprise при помощи R применять технол...
# 4    вчера в 22:40  Kotlin Android Extensions deprecated. Что дела...
#
#                                                intro  \
# 0  \n\nЧасть 1 ‣ Часть2 \n\r\nКосмические аппарат...
# 1  \n\n      Продолжение статьи "Введение в модел...
# 2  \n\n\nПриветствую,\nСначала о проблеме/задаче:...
# 3  \n\nКак-то так получилось, что в 2020 году воз...
# 4  \n\n      Возможно, вы уже слышали, что Kotlin...
#
#                                   a
# 0  https://habr.com/ru/post/526204/
# 1  https://habr.com/ru/post/525620/
# 2  https://habr.com/ru/post/526196/
# 3  https://habr.com/ru/post/526194/
# 4  https://habr.com/ru/post/526192/

# %%
len(news)
# Out:
# 996

# %%
table = pd.DataFrame()
for word in KEYWORDS:
    table1 = news[(news.header.str.contains(word)) | (news.intro.str.contains(word))]
    table = pd.concat([table, table1])
    
table
# Out:
#                         date  \
# 922  15 октября 2020 в 15:25
# 392  26 октября 2020 в 20:29
# 586  22 октября 2020 в 11:47
# 750  19 октября 2020 в 16:01
#
#                                                 header  \
# 922  Разработка онлайн-сервиса для инвесторов на py...
# 392  ZoomX. Меняем правила шаблонизации в MODX Revo...
# 586  Мелкая питонячая радость #11: реактивное прогр...
# 750                  Spark schemaEvolution на практике
#
#                                                  intro  \
# 922  \n\n      Цель настоящей статьи — поделиться о...
# 392  \n\n      Привет, друзья! Хорошая новость для ...
# 586  \n\n\nНа этой неделе мы посмотрим, как можно р...
# 750  \n\n      Уважаемые читатели, доброго дня!\n\r...
#
#                                                     a
# 922                  https://habr.com/ru/post/523612/
# 392                  https://habr.com/ru/post/525158/
# 586                  https://habr.com/ru/post/523878/
# 750  https://habr.com/ru/company/neoflex/blog/524080/

# %%
del table['intro']

# %%
table
# Out:
#                         date  \
# 922  15 октября 2020 в 15:25
# 392  26 октября 2020 в 20:29
# 586  22 октября 2020 в 11:47
# 750  19 октября 2020 в 16:01
#
#                                                 header  \
# 922  Разработка онлайн-сервиса для инвесторов на py...
# 392  ZoomX. Меняем правила шаблонизации в MODX Revo...
# 586  Мелкая питонячая радость #11: реактивное прогр...
# 750                  Spark schemaEvolution на практике
#
#                                                     a
# 922                  https://habr.com/ru/post/523612/
# 392                  https://habr.com/ru/post/525158/
# 586                  https://habr.com/ru/post/523878/
# 750  https://habr.com/ru/company/neoflex/blog/524080/

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Улучшить скрипт так, чтобы он анализировал не только preview-информацию статьи, но и весь текст статьи целиком.
#
# Для этого потребуется получать страницы статей и искать по тексту внутри этой страницы.
#
# Итоговый датафрейм формировать со столбцами: <дата> - <заголовок> - <ссылка> - <текст статьи>

# %% [markdown]
# ## Задание 2.

# %% [markdown]
# ### Обязательная часть

# %% [markdown]
# Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса [Avast Hack Ckeck](https://www.avast.com/hackcheck/).
# Список email-ов задаем переменной в начале кода:
# `EMAIL = [xxx@x.ru, yyy@y.com]`
#
# В итоге должен формироваться датафрейм со столбцами: <почта> - <дата утечки> - <источник утечки> - <описание утечки>.

# %%
import json
headers = {
    'Accept' :'application/json, text/plain, */*',
    'User-Agent':'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:82.0) Gecko/20100101 Firefox/82.0',
    'Content-Type':'application/json;charset=utf-8',
    'Accept-Encoding' : 'gzip, deflate, br' ,
    'Accept-Language' : 'ru-RU,ru;q=0.8,en-US;q=0.5,en;q=0.3' ,
    'Connection' : 'keep-alive',
    'Content-Length' :'31',
    'Content-Type' : 'application/json;charset=utf-8',
    'Host' : 'identityprotection.avast.com',
    'Origin' : 'https://www.avast.com',
    'Referer' : 'https://www.avast.com/hackcheck/',
    'User-Agent' : 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:82.0) Gecko/20100101 Firefox/82.0',
    'Vaar-Header-App-Product' : 'hackcheck-web-avast',
    'Vaar-Version': '0'
}
emails = ['xxx@x.ru', 'yyy@y.com']
URL = 'https://identityprotection.avast.com/v1/web/query/site-breaches/unauthorized-data'

table = pd.DataFrame()

for email in emails:
    response = requests.post(URL, headers=headers, json = {"emailAddresses":[email]})
    for breach_value in response.json()['breaches'].values():
        
        row = {'email': email, 'publishDate': breach_value['publishDate'], 'site': breach_value['site'], 'description': breach_value['description'] }
        table = pd.concat([table, pd.DataFrame([row])])  
        
table
# Out:
#        email           publishDate              site  \
# 0   xxx@x.ru  2019-03-28T00:00:00Z  verifications.io
# 0   xxx@x.ru  2020-05-21T00:00:00Z            vk.com
# 0   xxx@x.ru  2017-02-14T00:00:00Z    parapa.mail.ru
# 0   xxx@x.ru  2016-10-29T00:00:00Z            vk.com
# 0   xxx@x.ru  2016-10-21T00:00:00Z         adobe.com
# 0   xxx@x.ru  2017-02-14T00:00:00Z     cfire.mail.ru
# 0   xxx@x.ru  2017-01-31T00:00:00Z  cdprojektred.com
# 0   xxx@x.ru  2016-10-23T00:00:00Z         imesh.com
# 0  yyy@y.com  2020-01-03T00:00:00Z     azcentral.com
# 0  yyy@y.com  2020-05-28T00:00:00Z       wishbone.io
# 0  yyy@y.com  2017-11-04T00:00:00Z    myheritage.com
# 0  yyy@y.com  2019-06-13T00:00:00Z         canva.com
# 0  yyy@y.com  2016-10-24T00:00:00Z       dropbox.com
# 0  yyy@y.com  2016-10-21T00:00:00Z      linkedin.com
# 0  yyy@y.com  2017-03-01T00:00:00Z      rayli.com.cn
# 0  yyy@y.com  2019-10-17T00:00:00Z         zynga.com
# 0  yyy@y.com  2016-10-21T00:00:00Z         adobe.com
# 0  yyy@y.com  2018-02-18T00:00:00Z        netlog.com
# 0  yyy@y.com  2017-03-15T00:00:00Z    globalreach.eu
# 0  yyy@y.com  2016-10-23T00:00:00Z         imesh.com
# 0  yyy@y.com  2017-03-24T00:00:00Z         youku.com
#
#                                          description
# 0  Big data e-mail verification platform verifica...
# 0  At some time in 2020, the Russian social netwo...
# 0  In July and August 2016, two criminals execute...
# 0  Popular Russian social networking platform VKo...
# 0  In October of 2013, criminals penetrated Adobe...
# 0  In July and August of 2016, two criminals carr...
# 0  In March 2016, CDProjektRed.com.com's forum da...
# 0  In June 2016, a cache of over 51 million user ...
# 0  At an unconfirmed date, online Arizona newspap...
# 0  In January 2020, the online poll website Wishb...
# 0  In October 2017, a customer database belonging...
# 0  In May 2019, graphic-design site Canva's datab...
# 0  Cloud storage company Dropbox suffered a major...
# 0  In 2012, online professional networking platfo...
# 0  On an unconfirmed date, Chinese gossip site Ra...
# 0  In September 2019, the game developer Zynga wa...
# 0  In October of 2013, criminals penetrated Adobe...
# 0  Netlog (formerly known as Facebox and Bingbox)...
# 0  In 2016, Global Reach Technology's database wa...
# 0  In June 2016, a cache of over 51 million user ...
# 0  Youku is a large Chinese video content company...

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Написать скрипт, который будет получать 50 последних постов указанной группы во Вконтакте.
# Документация к API VK: https://vk.com/dev/methods
# , вам поможет метод [wall.get](https://vk.com/dev/wall.get)```
# GROUP = 'netology'
# TOKEN = УДАЛЯЙТЕ В ВЕРСИИ ДЛЯ ПРОВЕРКИ, НА GITHUB НЕ ВЫКЛАДЫВАТЬ
# ```
#
# В итоге должен формироваться датафрейм со столбцами: <дата поста> - <текст поста>.

# %% [markdown]
# #### ПРИМЕЧАНИЕ
# Домашнее задание сдается ссылкой на репозиторий [GitHub](https://github.com/).
# Не сможем проверить или помочь, если вы пришлете:
# - файлы;
# - архивы;
# - скриншоты кода.
#
# Все обсуждения и консультации по выполнению домашнего задания ведутся только на соответствующем канале в slack.
#
# ##### Как правильно задавать вопросы аспирантам, преподавателям и коллегам?
# Прежде чем задать вопрос необходимо попробовать найти ответ самому в интернете. Навык самостоятельного поиска информации – один из важнейших, и каждый практикующий специалист любого уровня это делает каждый день.
#
# Любой вопрос должен быть сформулирован по алгоритму:
# 1) Что я делаю?
# 2) Какого результата я ожидаю?
# 3) Как фактический результат отличается от ожидаемого?
# 4) Что я уже попробовал сделать, чтобы исправить проблему?
#
# По возможности, прикрепляйте к вопросу скриншоты, либо ссылки на код. Оставляйте только проблемный и воспроизводимый участок кода, все решение выкладывать не допускается.
